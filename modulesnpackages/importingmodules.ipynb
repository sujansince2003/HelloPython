# %%
import math;
math.sqrt(4)
# Out:
# 2.0

# %%
import math as mt
mt.sqrt(4)
# Out:
# 2.0

# %%
from mypackage.maths import addition
print(addition(4,5))
# Out:
# 9

# %%
from math import sqrt,pi
print(sqrt(4)) #sqrt(4)
print(pi)
# Out:
# 2.0
# 3.141592653589793
