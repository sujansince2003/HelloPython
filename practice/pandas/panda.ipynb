# %%
import pandas as pd


data = {
    "name": ["Sujan", "Ram", "Hari"],
    "age": [21, 22, 20],
    "city": ["Butwal", "Pokhara", "Kathmandu"]
}

# df = pd.DataFrame(data)
# print(df)
dff = pd.read_csv("contacts.csv")
# print(dff)
# print(dff.info)
# print(dff.describe)
print(dff.Name)
# Out:
# 0      sujan
# 1       prem
# 2     raqavi
# 3      hello
# 4      sdfsd
# 5    fergerg
# Name: Name, dtype: object
