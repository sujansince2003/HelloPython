# %%
numbers=[1,2,3,4,5,6]

def square(n):
    return n*2
double_numbers= map(square,numbers)
print(list(double_numbers))



triple_numbers= list(map(lambda x:x*3,numbers))
print(triple_numbers)
# Out:
# [2, 4, 6, 8, 10, 12]
# [3, 6, 9, 12, 15, 18]
