# %%
def sayHello(name):
    print("hello " + name)

sayHello("sujan")    


# variables and length arguments  


def printNum(*args):
    num1=args[0]
    num2=args[1]
    print(num1 , num2)
    for num in args:
        print(num)

printNum(54,32)

age=4
if (age<5 and age==4) :
    print("cool")
# Out:
# hello sujan
# 54 32
# 54
# 32
# cool
