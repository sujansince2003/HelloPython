# %%
class Person:
    course_type= "IT/Engineering"

    def __init__(self,course_name,fee):
        self.course_name= course_name
        self.fee= fee
        print("this is awesome")

    def saycoursename(self):
        print(self.course_name)   



class CSIT(Person):
    def __init__(self,course_name,fee):
        super().__init__(course_name,fee)
        print(fee)
        self.saycoursename()


per= CSIT("csit",3000)
# Out:
# this is awesome
# 3000
# csit
