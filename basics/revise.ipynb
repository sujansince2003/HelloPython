# %%
# # type converting
# a = "2"
# print(int(a)+4)
# print(a+"fnd")

# b= 4.5
# print(type(b))
# fname = "i am sujan khatri"
# print(len(fname))


# lname = f"this is {fname}"
# print(lname)


# lname="xKhatrisx"
# course="csit is best course.you can pursue csit in bachelors"
# fee="$1.423$ggfk"

# lower_lname = lname.lower()
# upper_lname = lname.upper()

# strip_lname = lname.strip()
# print(lower_lname)
# print(upper_lname)
# print(strip_lname)

# print(fee.strip("$"))


# print("khatri" in lname)
# print(course.startswith("csit"))
# print(course.endswith("course"))
# print(course.find("csit"))
# print(course.count("csit"))
# replace_csit= course.replace("csit","Btech")
# print(replace_csit)



# age =24
# if age>20:
#     print("cool age is above 20")


# if (age>20 and age==24):
#     print("age is 24 and ")

# if (age>20 or age==24):
#     print("age is 24 and ")

# if not age<20:
#     print("no name given")



for i in range(3):
    print(i)


fname = "sujan is cool"
j=0
for i in fname:
    
    print(i)
   
    j=j+1
    print(j)
print(len(fname))
# Out:
# 0
# 1
# 2
# s
# 1
# u
# 2
# j
# 3
# a
# 4
# n
# 5
#
# 6
# i
# 7
# s
# 8
#
# 9
# c
# 10
# o
# 11
# o
# 12
# l
# 13
# 13
