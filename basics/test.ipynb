# %%
count=0
while count<5:
    print(count);
    count=count+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
fname="sujan";
for i in fname:
    print(i)
# Out:
# s
# u
# j
# a
# n

# %%
for i in range(8,2,-2):
    print(i)
# Out:
# 8
# 6
# 4

# %%
for i in range(2,8,2):
    print(i)
# Out:
# 2
# 4
# 6

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
b=4
a=b
print(a)
print(b)
# Out:
# 4
# 4

# %%
''' 
line continuation character is \
used to split a single statement into multiple lines
'''
total=1+2+3+\
 4+5
print(total)
# Out:
# 15

# %%
print(1+1)
# Out:
# 2

# %%
age=32
if age>18:
    print("You are an adult")
else:
    print("You are a minor")
# Out:
# You are an adult
