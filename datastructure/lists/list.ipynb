# %%
# lists in python
fruits=["apple","banana","mango"]
print(fruits)


# access elements
print(fruits[0])
print(fruits[-1])


# modify elements
fruits[0]="guava"
print(fruits)


# add elements
fruits.append("kiwi")
fruits.insert(1,"dragon")

print(fruits)
# Out:
# ['apple', 'banana', 'mango']
# apple
# mango
# ['guava', 'banana', 'mango']
# ['dragon', 'guava', 'banana', 'mango', 'kiwi']
